# %%
import os, sys
import numpy as np
import twint
import pandas as pd
from datetime import datetime, timedelta, date
import nest_asyncio
nest_asyncio.apply()

# %%
os.chdir('C:/Users/alexi/Desktop/MS-DSPP/Spring 2022/PPOL628 Final Project')

# %%
df = pd.read_csv('governors.csv')

# %%
df.columns
# Out:
# Index(['State', 'StateAbbr', 'Name', 'Party', 'Inauguration', 'Title',
#        'office', 'officialTwitter', 'campaignTwitter', 'othertwitter'],
#       dtype='object')

# %%
df = df.melt(id_vars = ['State',
                        'StateAbbr',
                        'Name',
                        'Party',
                        'Inauguration',
                        'Title',
                        'office'],
            value_vars = ['officialTwitter',
                          'campaignTwitter',
                          'othertwitter'],
            var_name = 'account_type',
            value_name = 'twitter')

# %%
df['filename'] = df['StateAbbr']+'_'+df['office']+'_'+df['account_type']
df['filename'] = df['filename'].astype(str).replace(" ", "_")

# %%
df = df.dropna(subset = ['twitter']).reset_index(drop = True)

# %%
df['Inauguration'] = df['Inauguration'].datetime.strptime('%d-%b-%Y').strftime('%d%d/%m%m/%Y%Y%Y%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e501a37d94eb> in <module>
# ----> 1 df['Inauguration'] = df['Inauguration'].datetime.strptime('%d-%b-%Y').strftime('%d%d/%m%m/%Y%Y%Y%Y')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
def scraper(data, year):
    year1 = str(year)
    data = data.reset_index(drop = True)
    for i in range(0, len(data)):
        suffix = '.csv'
        dir_name = 'C:/Users/alexi/Desktop/MS-DSPP/Spring 2022/PPOL628 Final Project/scraped_tweets'
        file_name = data.loc[i, 'filename']+'_'+year1

        config = twint.Config()
        config.Username = data.loc[i, 'twitter']
        config.Since = year1+'-01-'+'01'
        config.Until = year1+'-12-'+'31'
    #config.Near = df_2021.loc[i, 'locality']
        config.Limit = 100000
        config.Output = os.path.join(dir_name, file_name+suffix)
        config.Hide_output = True
        config.Profile_full = True
    #config.Custom["tweet"] = ["id", "conversation_id", "date", "time", "user_id", 
    #                          "username", "name", "tweet", "language", "retweet", 
    #                          "retweets_count", "replies_count", "likes_count", 
    #                          "hashtags", "link", "video"]
        config.Store_csv = True

        try:
            print(data.loc[i, 'filename'], " ", i+1, "of", len(data))
        #config.Search = df_2021.loc[i, 'keywords']
        #'"covid" OR "covid-19" OR "coronavirus" OR "COVID-19" OR "mask" OR "vaccine" OR "mandate"'
            twint.run.Search(config)
    
        except ValueError:
            continue

# %%
scraper(df[254:], 2022)
# Out:
# KY_Governor_campaignTwitter   1 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# KY_LtGov_campaignTwitter   2 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# KY_StateAG_campaignTwitter   3 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# KY_Treasurer_campaignTwitter   4 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# LA_Governor_campaignTwitter   5 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# LA_LtGov_campaignTwitter   6 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# LA_StateAG_campaignTwitter   7 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# LA_Treasurer_campaignTwitter   8 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ME_Governor_campaignTwitter   9 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ME_Treasurer_campaignTwitter   10 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MD_Governor_campaignTwitter   11 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MD_StateAG_campaignTwitter   12 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MA_Governor_campaignTwitter   13 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MA_LtGov_campaignTwitter   14 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MA_SecState_campaignTwitter   15 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MA_StateAG_campaignTwitter   16 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MA_Treasurer_campaignTwitter   17 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MI_Governor_campaignTwitter   18 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MI_LtGov_campaignTwitter   19 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MI_SecState_campaignTwitter   20 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MI_StateAG_campaignTwitter   21 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MN_Governor_campaignTwitter   22 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MN_LtGov_campaignTwitter   23 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MN_StateAG_campaignTwitter   24 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MS_LtGov_campaignTwitter   25 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MS_Treasurer_campaignTwitter   26 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MO_Governor_campaignTwitter   27 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MO_SecState_campaignTwitter   28 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MO_StateAG_campaignTwitter   29 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MO_Treasurer_campaignTwitter   30 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MT_Governor_campaignTwitter   31 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# MT_SecState_campaignTwitter   32 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NE_Governor_campaignTwitter   33 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NV_Governor_campaignTwitter   34 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NV_LtGov_campaignTwitter   35 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NV_StateAG_campaignTwitter   36 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NV_Treasurer_campaignTwitter   37 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NH_Governor_campaignTwitter   38 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NH_StateAG_campaignTwitter   39 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NJ_Governor_campaignTwitter   40 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NJ_LtGov_campaignTwitter   41 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NJ_StateAG_campaignTwitter   42 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NJ_Treasurer_campaignTwitter   43 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NM_Governor_campaignTwitter   44 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NM_LtGov_campaignTwitter   45 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NM_SecState_campaignTwitter   46 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NM_StateAG_campaignTwitter   47 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NY_Governor_campaignTwitter   48 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NY_LtGov_campaignTwitter   49 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NY_StateAG_campaignTwitter   50 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NY_Treasurer_campaignTwitter   51 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NC_Governor_campaignTwitter   52 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NC_LtGov_campaignTwitter   53 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NC_SecState_campaignTwitter   54 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NC_StateAG_campaignTwitter   55 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# NC_Treasurer_campaignTwitter   56 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ND_Governor_campaignTwitter   57 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ND_LtGov_campaignTwitter   58 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ND_StateAG_campaignTwitter   59 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OH_Governor_campaignTwitter   60 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OH_LtGov_campaignTwitter   61 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OH_SecState_campaignTwitter   62 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OH_StateAG_campaignTwitter   63 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OH_Treasurer_campaignTwitter   64 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OK_Governor_campaignTwitter   65 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OK_LtGov_campaignTwitter   66 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OR_Governor_campaignTwitter   67 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OR_SecState_campaignTwitter   68 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OR_StateAG_campaignTwitter   69 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# OR_Treasurer_campaignTwitter   70 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# PA_Governor_campaignTwitter   71 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# PA_LtGov_campaignTwitter   72 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# PA_StateAG_campaignTwitter   73 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# PA_Treasurer_campaignTwitter   74 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# RI_Governor_campaignTwitter   75 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# RI_LtGov_campaignTwitter   76 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# RI_SecState_campaignTwitter   77 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# RI_StateAG_campaignTwitter   78 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# RI_Treasurer_campaignTwitter   79 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# SC_StateAG_campaignTwitter   80 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# SD_Governor_campaignTwitter   81 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# SD_StateAG_campaignTwitter   82 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TN_Governor_campaignTwitter   83 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TN_Treasurer_campaignTwitter   84 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TX_Governor_campaignTwitter   85 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TX_LtGov_campaignTwitter   86 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TX_StateAG_campaignTwitter   87 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TX_Treasurer_campaignTwitter   88 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# UT_Governor_campaignTwitter   89 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# UT_LtGov_campaignTwitter   90 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# UT_StateAG_campaignTwitter   91 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VT_Governor_campaignTwitter   92 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VT_LtGov_campaignTwitter   93 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VT_StateAG_campaignTwitter   94 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VT_Treasurer_campaignTwitter   95 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VA_Governor_campaignTwitter   96 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VA_LtGov_campaignTwitter   97 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VA_SecState_campaignTwitter   98 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# VA_StateAG_campaignTwitter   99 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WA_Governor_campaignTwitter   100 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WA_LtGov_campaignTwitter   101 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WA_SecState_campaignTwitter   102 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WA_StateAG_campaignTwitter   103 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WV_Governor_campaignTwitter   104 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WV_LtGov_campaignTwitter   105 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WV_SecState_campaignTwitter   106 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WV_StateAG_campaignTwitter   107 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WV_Treasurer_campaignTwitter   108 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WI_Governor_campaignTwitter   109 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WI_LtGov_campaignTwitter   110 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WI_SecState_campaignTwitter   111 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WI_StateAG_campaignTwitter   112 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WI_Treasurer_campaignTwitter   113 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WY_Governor_campaignTwitter   114 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# WY_SecState_campaignTwitter   115 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# CO_Governor_othertwitter   116 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# KY_StateAG_othertwitter   117 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# TX_Governor_othertwitter   118 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# UT_Governor_othertwitter   119 of 119
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
import glob

# %%
path = 'C:/Users/alexi/Desktop/MS-DSPP/Spring 2022/PPOL628 Final Project/scraped_tweets' # use your path
globbed_files = glob.glob(path + "/*.csv")

# %%
data = []
for csv in globbed_files:
    frame = pd.read_csv(csv)
    frame['filename'] = os.path.basename(csv)
    data.append(frame)

# %%
data = pd.concat(data, ignore_index = True)

# %%
data.shape
# Out:
# (31758, 37)
